# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import pandas as pd
import os, sys
import cv2
import PIL
import time
from skimage import color
import os.path
from PIL import Image, ImageOps

# %%
cwd = os.getcwd()
# os.listdir(cwd)

# %%
training_paths = ["./train_tumor/Tumor/", "./train_tumor4/NoTumor/"]
test_paths = ["./test_tumor/Tumor/", "./test_tumor4/NoTumor/"]

# %%
# Resizing an saving the training images in same folder with same file name

for path in training_paths:
    for img_name in os.listdir(path):
        f_img = path+img_name
        img = Image.open(f_img)
        img_gray = img.convert('L')
        try:
            img_gray = img_gray.resize((300,300), PIL.Image.ANTIALIAS)
            img_gray.save(f_img, quality=95)
        except ValueError:
            print("There is something wrong")

# %%
# Resizing an saving the test images in same folder with same file name

for path in test_paths:
    for img_name in os.listdir(path):
        f_img = path+img_name
        img = Image.open(f_img)
        img_gray = img.convert('L')
        try:
            img_gray = img_gray.resize((300,300), PIL.Image.ANTIALIAS)
            img_gray.save(f_img, quality=95)
        except ValueError:
            print("There is something wrong")

# %%
train = ImageDataGenerator(rescale=1/255)
test = ImageDataGenerator(rescale=1/255)

train_dataset = train.flow_from_directory("train_tumor4",
                                          target_size=(300,300),
                                          batch_size = 32,
                                          class_mode = 'binary', color_mode="grayscale")

test_dataset = test.flow_from_directory("test_tumor4",
                                          target_size=(300,300),
                                          batch_size =32,
                                          class_mode = 'binary', color_mode="grayscale")
# Out:
# Found 88 images belonging to 2 classes.
# Found 22 images belonging to 2 classes.

# %%
test_dataset.class_indices
# Out:
# {'NoTumor': 0, 'Tumor': 1}

# %%
train_dataset.class_indices
# Out:
# {'NoTumor': 0, 'Tumor': 1}

# %%
model = keras.Sequential()

# Convolutional layer and maxpool layer 1
model.add(keras.layers.Conv2D(32,(3,3),activation='relu',input_shape=(300,300,1)))
model.add(keras.layers.MaxPool2D(2,2))

# Convolutional layer and maxpool layer 2
model.add(keras.layers.Conv2D(64,(3,3),activation='relu'))
model.add(keras.layers.MaxPool2D(2,2))

# Convolutional layer and maxpool layer 3
model.add(keras.layers.Conv2D(128,(3,3),activation='relu'))
model.add(keras.layers.MaxPool2D(2,2))

# Convolutional layer and maxpool layer 4
model.add(keras.layers.Conv2D(128,(3,3),activation='relu'))
model.add(keras.layers.MaxPool2D(2,2))

# This layer flattens the resulting image array to 1D array
model.add(keras.layers.Flatten())

# Hidden layer with 512 neurons and Rectified Linear Unit activation function 
model.add(keras.layers.Dense(512,activation='relu'))

# Output layer with single neuron which gives 0 for Cat or 1 for Dog 
#Here we use sigmoid activation function which makes our model output to lie between 0 and 1
model.add(keras.layers.Dense(1,activation='sigmoid'))

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %% [markdown]
# #steps_per_epoch = train_imagesize/batch_size
#
# start = time.time()
#
# model.fit(train_dataset,
#          epochs = 30, batch_size=10,
#          validation_data = 0.0
#          )
#
# end = time.time()
# print(end - start)

# %%
#steps_per_epoch = train_imagesize/batch_size
result = 0
model_300 = []
start = time.time()
for i in range(5):
    model.fit(train_dataset,
             epochs = 10, batch_size=10,
             validation_data = 0.0  
             )
    result = model.evaluate(test_dataset)
    model_300.append(result[1])
end = time.time()
print(end - start)
# Out:
# Epoch 1/10
# 3/3 [==============================] - 5s 1s/step - loss: 0.7397 - accuracy: 0.5455
# Epoch 2/10
# 3/3 [==============================] - 5s 1s/step - loss: 0.5254 - accuracy: 0.8750
# Epoch 3/10
# 3/3 [==============================] - 5s 2s/step - loss: 0.3024 - accuracy: 0.8523
# Epoch 4/10
# 3/3 [==============================] - 5s 2s/step - loss: 0.2701 - accuracy: 0.8977
# Epoch 5/10
# 3/3 [==============================] - 5s 2s/step - loss: 0.3547 - accuracy: 0.8636
# Epoch 6/10
# 3/3 [==============================] - 5s 1s/step - loss: 0.2337 - accuracy: 0.8977
# Epoch 7/10
# 3/3 [==============================] - 5s 2s/step - loss: 0.1925 - accuracy: 0.9432
# Epoch 8/10
# 3/3 [==============================] - 5s 2s/step - loss: 0.1326 - accuracy: 0.9545
# Epoch 9/10
# 3/3 [==============================] - 5s 2s/step - loss: 0.1635 - accuracy: 0.9545
# Epoch 10/10
# 3/3 [==============================] - 5s 2s/step - loss: 0.0821 - accuracy: 0.9659
# 1/1 [==============================] - 0s 497ms/step - loss: 0.2468 - accuracy: 0.8182
# Epoch 1/10
# 3/3 [==============================] - 5s 2s/step - loss: 0.0716 - accuracy: 0.9545
# Epoch 2/10
# 3/3 [==============================] - 5s 2s/step - loss: 0.0471 - accuracy: 0.9886
# Epoch 3/10
# 3/3 [==============================] - 5s 2s/step - loss: 0.0269 - accuracy: 0.9886
# Epoch 4/10
# 3/3 [==============================] - 5s 1s/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 5/10
# 3/3 [==============================] - 5s 1s/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 6/10
# 3/3 [==============================] - 5s 2s/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 7/10
# 3/3 [==============================] - 5s 2s/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 8/10
# 3/3 [==============================] - 5s 1s/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 9/10
# 3/3 [==============================] - 5s 2s/step - loss: 1.6681e-04 - accuracy: 1.0000
# Epoch 10/10
# 3/3 [==============================] - 5s 2s/step - loss: 1.2832e-04 - accuracy: 1.0000
# 1/1 [==============================] - 0s 330ms/step - loss: 0.1079 - accuracy: 0.9545
# Epoch 1/10
# 3/3 [==============================] - 5s 1s/step - loss: 1.6135e-04 - accuracy: 1.0000
# Epoch 2/10
# 3/3 [==============================] - 5s 2s/step - loss: 1.5818e-04 - accuracy: 1.0000
# Epoch 3/10
# 3/3 [==============================] - 5s 2s/step - loss: 1.0698e-04 - accuracy: 1.0000
# Epoch 4/10
# 3/3 [==============================] - 5s 1s/step - loss: 7.3356e-05 - accuracy: 1.0000
# Epoch 5/10
# 3/3 [==============================] - 5s 2s/step - loss: 4.1095e-05 - accuracy: 1.0000
# Epoch 6/10
# 3/3 [==============================] - 5s 2s/step - loss: 2.3159e-05 - accuracy: 1.0000
# Epoch 7/10
# 3/3 [==============================] - 5s 2s/step - loss: 1.6971e-05 - accuracy: 1.0000
# Epoch 8/10
# 3/3 [==============================] - 5s 2s/step - loss: 1.5547e-05 - accuracy: 1.0000
# Epoch 9/10
# 3/3 [==============================] - 5s 1s/step - loss: 1.5771e-05 - accuracy: 1.0000
# Epoch 10/10
# 3/3 [==============================] - 5s 2s/step - loss: 1.5371e-05 - accuracy: 1.0000
# 1/1 [==============================] - 0s 330ms/step - loss: 0.2393 - accuracy: 0.8636
# Epoch 1/10
# 3/3 [==============================] - 5s 2s/step - loss: 1.5319e-05 - accuracy: 1.0000
# Epoch 2/10
# 3/3 [==============================] - 5s 2s/step - loss: 1.4880e-05 - accuracy: 1.0000
# Epoch 3/10
# 3/3 [==============================] - 5s 2s/step - loss: 1.4526e-05 - accuracy: 1.0000
# Epoch 4/10
# 3/3 [==============================] - 5s 2s/step - loss: 1.3940e-05 - accuracy: 1.0000
# Epoch 5/10
# 3/3 [==============================] - 5s 2s/step - loss: 1.3389e-05 - accuracy: 1.0000
# Epoch 6/10
# 3/3 [==============================] - 5s 2s/step - loss: 1.2699e-05 - accuracy: 1.0000
# Epoch 7/10
# 3/3 [==============================] - 5s 2s/step - loss: 1.2213e-05 - accuracy: 1.0000
# Epoch 8/10
# 3/3 [==============================] - 5s 2s/step - loss: 1.1624e-05 - accuracy: 1.0000
# Epoch 9/10
# 3/3 [==============================] - 5s 2s/step - loss: 1.1147e-05 - accuracy: 1.0000
# Epoch 10/10
# 3/3 [==============================] - 5s 2s/step - loss: 1.0933e-05 - accuracy: 1.0000
# 1/1 [==============================] - 0s 376ms/step - loss: 0.2079 - accuracy: 0.8636
# Epoch 1/10
# 3/3 [==============================] - 5s 2s/step - loss: 1.0674e-05 - accuracy: 1.0000
# Epoch 2/10
# 3/3 [==============================] - 5s 2s/step - loss: 1.0296e-05 - accuracy: 1.0000
# Epoch 3/10
# 3/3 [==============================] - 5s 2s/step - loss: 1.0071e-05 - accuracy: 1.0000
# Epoch 4/10
# 3/3 [==============================] - 5s 2s/step - loss: 9.9573e-06 - accuracy: 1.0000
# Epoch 5/10
# 3/3 [==============================] - 5s 2s/step - loss: 9.6708e-06 - accuracy: 1.0000
# Epoch 6/10
# 3/3 [==============================] - 5s 2s/step - loss: 9.5010e-06 - accuracy: 1.0000
# Epoch 7/10
# 3/3 [==============================] - 5s 2s/step - loss: 9.3311e-06 - accuracy: 1.0000
# Epoch 8/10
# 3/3 [==============================] - 6s 2s/step - loss: 9.1827e-06 - accuracy: 1.0000
# Epoch 9/10
# 3/3 [==============================] - 5s 2s/step - loss: 9.0216e-06 - accuracy: 1.0000
# Epoch 10/10
# 3/3 [==============================] - 5s 2s/step - loss: 8.9299e-06 - accuracy: 1.0000
# 1/1 [==============================] - 0s 353ms/step - loss: 0.1904 - accuracy: 0.8636
# 250.16289353370667

# %%
print(model_300)
print(np.mean(model_300))
# Out:
# [0.8181818127632141, 0.9545454382896423, 0.8636363744735718, 0.8636363744735718, 0.8636363744735718]
# 0.8727272748947144

# %%
model.evaluate(test_dataset)
# Out:
# 1/1 [==============================] - 0s 361ms/step - loss: 0.1904 - accuracy: 0.8636
# [0.1904265433549881, 0.8636363744735718]

# %%
# Predicting single image
from skimage import transform
def load(filename):
    np_image = Image.open(filename)
    np_image = np.array(np_image).astype('float32')/255
    np_image = transform.resize(np_image, (300, 300, 1))
    np_image = np.expand_dims(np_image, axis=0)
    return np_image

image = load('./test_tumor4/Tumor/Tr-me_0076.jpg')
model.predict(image)
# Out:
# array([[0.99996334]], dtype=float32)

# %%
# Predicting single image
from skimage import transform
def load(filename):
    np_image = Image.open(filename)
    np_image = np.array(np_image).astype('float32')/255
    np_image = transform.resize(np_image, (300, 300, 1))
    np_image = np.expand_dims(np_image, axis=0)
    return np_image

image = load('./test_tumor4/NoTumor/Tr-no_0054.jpg')
model.predict(image)
# Out:
# array([[1.847002e-37]], dtype=float32)

# %%
dd = os.listdir("./train_tumor4/Tumor/")
rgb = plt.imread('./train_tumor4/Tumor/Tr-me_0010.jpg')
plt.imshow(rgb)

# %%
"""

#steps_per_epoch = train_imagesize/batch_size

model.fit_generator(train_dataset,
         steps_per_epoch = 250,
         epochs = 10,
         validation_data = test_dataset
       
         )
         
"""
# Out:
# '\n\n#steps_per_epoch = train_imagesize/batch_size\n\nmodel.fit_generator(train_dataset,\n         steps_per_epoch = 250,\n         epochs = 10,\n         validation_data = test_dataset\n       \n         )\n         \n'

# %%
"""

# Manually Predicting 
test_path = '../test_tumor'
Tumor=0
NoTumor=0
for i in os.listdir(test_path):
    img = image.load_img(test_path + "//" +i, target_size=(512,512,3))
    plt.imshow(img)
    plt.show()
    X = image.img_to_array(img)
    X = np.expand_dims(X, axis=0)
    images = np.vstack([X])
    val = model.predict(images)
    if val == 0:
        NoTumor +=1
        print('NoTumor')
    else:
        Tumor +=1
        print('Tumor')
print(f'Tumor: {Tumor}, NoTumor: {NoTumor}')


"""
# Out:
# '\n\n# Manually Predicting \ntest_path = \'../test_tumor\'\nTumor=0\nNoTumor=0\nfor i in os.listdir(test_path):\n    img = image.load_img(test_path + "//" +i, target_size=(512,512,3))\n    plt.imshow(img)\n    plt.show()\n    X = image.img_to_array(img)\n    X = np.expand_dims(X, axis=0)\n    images = np.vstack([X])\n    val = model.predict(images)\n    if val == 0:\n        NoTumor +=1\n        print(\'NoTumor\')\n    else:\n        Tumor +=1\n        print(\'Tumor\')\nprint(f\'Tumor: {Tumor}, NoTumor: {NoTumor}\')\n\n\n'

# %%
"""

def predictImage(filename):
    img1 = image.load_img(filename,target_size=(224,224))
    
    plt.imshow(img1)
 
    Y = image.img_to_array(img1)
    
    X = np.expand_dims(Y,axis=0)
    val = model.predict(X)
    print(val)
    if val == 1:
        
        plt.xlabel("Duck",fontsize=20)
        
    
    elif val == 0:
        
        plt.xlabel("Bird",fontsize=20)


"""
# Out:
# '\n\ndef predictImage(filename):\n    img1 = image.load_img(filename,target_size=(224,224))\n    \n    plt.imshow(img1)\n \n    Y = image.img_to_array(img1)\n    \n    X = np.expand_dims(Y,axis=0)\n    val = model.predict(X)\n    print(val)\n    if val == 1:\n        \n        plt.xlabel("Duck",fontsize=20)\n        \n    \n    elif val == 0:\n        \n        plt.xlabel("Bird",fontsize=20)\n\n\n'
