# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
import os
import cv2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt

# %%
DATADIR_TRAIN = "../train_bird"
DATADIR_VALID = "../validation_bird"
DATADIR_TEST = "../test_bird"
CATEGORIES = ["bird", "duck"]

# %%
train = ImageDataGenerator(rescale=1/255)
test = ImageDataGenerator(rescale=1/255)

train_dataset = train.flow_from_directory("../train_bird",
                                          target_size=(224,224),
                                          batch_size = 32,
                                          class_mode = 'binary')
                                         
validation_dataset = test.flow_from_directory("../validation_bird",
                                          target_size=(224,224),
                                          batch_size =32,
                                          class_mode = 'binary')
# Out:
# Found 228 images belonging to 2 classes.
# Found 26 images belonging to 2 classes.

# %%
validation_dataset.class_indices
# Out:
# {'bird': 0, 'duck': 1}

# %%
train_dataset.class_indices
# Out:
# {'bird': 0, 'duck': 1}

# %%
model = keras.Sequential()

# Convolutional layer and maxpool layer 1
model.add(keras.layers.Conv2D(32,(3,3),activation='relu',input_shape=(224,224,3)))
model.add(keras.layers.MaxPool2D(2,2))

# Convolutional layer and maxpool layer 2
model.add(keras.layers.Conv2D(64,(3,3),activation='relu'))
model.add(keras.layers.MaxPool2D(2,2))

# Convolutional layer and maxpool layer 3
model.add(keras.layers.Conv2D(128,(3,3),activation='relu'))
model.add(keras.layers.MaxPool2D(2,2))

# Convolutional layer and maxpool layer 4
model.add(keras.layers.Conv2D(128,(3,3),activation='relu'))
model.add(keras.layers.MaxPool2D(2,2))

# This layer flattens the resulting image array to 1D array
model.add(keras.layers.Flatten())

# Hidden layer with 512 neurons and Rectified Linear Unit activation function 
model.add(keras.layers.Dense(512,activation='relu'))

# Output layer with single neuron which gives 0 for Cat or 1 for Dog 
#Here we use sigmoid activation function which makes our model output to lie between 0 and 1
model.add(keras.layers.Dense(1,activation='sigmoid'))

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
#steps_per_epoch = train_imagesize/batch_size

model.fit(train_dataset,
         epochs = 20, batch_size=10,
         validation_data = validation_dataset  
         )
# Out:
# Epoch 1/30
# 8/8 [==============================] - 8s 968ms/step - loss: 0.7791 - accuracy: 0.5175 - val_loss: 0.7606 - val_accuracy: 0.5000
# Epoch 2/30
# 8/8 [==============================] - 7s 921ms/step - loss: 0.5865 - accuracy: 0.7061 - val_loss: 0.6406 - val_accuracy: 0.5769
# Epoch 3/30
# 8/8 [==============================] - 8s 943ms/step - loss: 0.4444 - accuracy: 0.8246 - val_loss: 0.7119 - val_accuracy: 0.6538
# Epoch 4/30
# 8/8 [==============================] - 7s 923ms/step - loss: 0.6897 - accuracy: 0.6886 - val_loss: 0.5538 - val_accuracy: 0.6923
# Epoch 5/30
# 8/8 [==============================] - 7s 923ms/step - loss: 0.4142 - accuracy: 0.8640 - val_loss: 0.6619 - val_accuracy: 0.6923
# Epoch 6/30
# 8/8 [==============================] - 7s 908ms/step - loss: 0.2961 - accuracy: 0.8860 - val_loss: 0.6753 - val_accuracy: 0.6538
# Epoch 7/30
# 8/8 [==============================] - 8s 932ms/step - loss: 0.2361 - accuracy: 0.8904 - val_loss: 0.6647 - val_accuracy: 0.7308
# Epoch 8/30
# 8/8 [==============================] - 8s 948ms/step - loss: 0.2910 - accuracy: 0.8772 - val_loss: 0.6133 - val_accuracy: 0.6923
# Epoch 9/30
# 8/8 [==============================] - 8s 1s/step - loss: 0.2566 - accuracy: 0.9123 - val_loss: 0.8906 - val_accuracy: 0.6923
# Epoch 10/30
# 8/8 [==============================] - 8s 934ms/step - loss: 0.2511 - accuracy: 0.9079 - val_loss: 0.5515 - val_accuracy: 0.8077
# Epoch 11/30
# 8/8 [==============================] - 8s 925ms/step - loss: 0.2250 - accuracy: 0.9254 - val_loss: 0.5155 - val_accuracy: 0.7692
# Epoch 12/30
# 8/8 [==============================] - 7s 905ms/step - loss: 0.1780 - accuracy: 0.9079 - val_loss: 1.2239 - val_accuracy: 0.5769
# Epoch 13/30
# 8/8 [==============================] - 8s 950ms/step - loss: 0.1479 - accuracy: 0.9430 - val_loss: 0.9237 - val_accuracy: 0.7308
# Epoch 14/30
# 8/8 [==============================] - 8s 949ms/step - loss: 0.1072 - accuracy: 0.9605 - val_loss: 1.2363 - val_accuracy: 0.6923
# Epoch 15/30
# 8/8 [==============================] - 7s 896ms/step - loss: 0.0839 - accuracy: 0.9649 - val_loss: 1.2727 - val_accuracy: 0.6538
# Epoch 16/30
# 8/8 [==============================] - 8s 933ms/step - loss: 0.0947 - accuracy: 0.9649 - val_loss: 1.5434 - val_accuracy: 0.7692
# Epoch 17/30
# 8/8 [==============================] - 8s 933ms/step - loss: 0.0896 - accuracy: 0.9561 - val_loss: 2.1107 - val_accuracy: 0.7308
# Epoch 18/30
# 8/8 [==============================] - 8s 935ms/step - loss: 0.0518 - accuracy: 0.9868 - val_loss: 1.1381 - val_accuracy: 0.7308
# Epoch 19/30
# 8/8 [==============================] - 7s 902ms/step - loss: 0.0289 - accuracy: 0.9956 - val_loss: 2.5208 - val_accuracy: 0.7308
# Epoch 20/30
# 8/8 [==============================] - 7s 912ms/step - loss: 0.0558 - accuracy: 0.9781 - val_loss: 1.9996 - val_accuracy: 0.7308
# Epoch 21/30
# 8/8 [==============================] - 7s 908ms/step - loss: 0.0210 - accuracy: 0.9912 - val_loss: 1.5159 - val_accuracy: 0.6923
# Epoch 22/30
# 8/8 [==============================] - 7s 920ms/step - loss: 0.1773 - accuracy: 0.9518 - val_loss: 1.4312 - val_accuracy: 0.6538
# Epoch 23/30
# 8/8 [==============================] - 7s 915ms/step - loss: 0.0789 - accuracy: 0.9518 - val_loss: 4.6230 - val_accuracy: 0.6923
# Epoch 24/30
# 8/8 [==============================] - 8s 940ms/step - loss: 0.1517 - accuracy: 0.9474 - val_loss: 2.8084 - val_accuracy: 0.7308
# Epoch 25/30
# 8/8 [==============================] - 8s 960ms/step - loss: 0.0735 - accuracy: 0.9693 - val_loss: 0.7251 - val_accuracy: 0.6923
# Epoch 26/30
# 8/8 [==============================] - 8s 1s/step - loss: 0.0398 - accuracy: 0.9912 - val_loss: 1.2017 - val_accuracy: 0.7692
# Epoch 27/30
# 8/8 [==============================] - 7s 923ms/step - loss: 0.0181 - accuracy: 0.9956 - val_loss: 1.5353 - val_accuracy: 0.7692
# Epoch 28/30
# 8/8 [==============================] - 8s 944ms/step - loss: 0.0108 - accuracy: 0.9956 - val_loss: 1.2912 - val_accuracy: 0.7692
# Epoch 29/30
# 8/8 [==============================] - 8s 947ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 1.4775 - val_accuracy: 0.7692
# Epoch 30/30
# 8/8 [==============================] - 8s 975ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 1.5367 - val_accuracy: 0.7692

# %% [markdown]
# #steps_per_epoch = train_imagesize/batch_size
#
# model.fit_generator(train_dataset,
#          steps_per_epoch = 250,
#          epochs = 10,
#          validation_data = test_dataset
#
#          )

# %%
# Manually Predicting 
test_path = '../test_bird1'
Bird=0
Duck=0
for i in os.listdir(test_path):
    img = image.load_img(test_path + "//" +i, target_size=(224,224,3))
    plt.imshow(img)
    plt.show()
    X = image.img_to_array(img)
    X = np.expand_dims(X, axis=0)
    images = np.vstack([X])
    val = model.predict(images)
    if val == 0:
        Bird +=1
        print('Bird')
    else:
        Duck +=1
        print('Duck')
print(f'Bird: {Bird}, Duck: {Duck}')
# Out:
# Bird
# Bird
# Bird
# Bird
# Duck
# Bird
# Duck
# Duck
# Duck
# Duck
# Duck
# Duck
# Duck
# Bird
# Bird
# Bird
# Duck
# Duck
# Duck
# Duck
# Duck
# Duck
# Duck
# Bird
# Bird
# Bird
# Bird: 11, Duck: 15

# %% [markdown]
# def predictImage(filename):
#     img1 = image.load_img(filename,target_size=(224,224))
#
#     plt.imshow(img1)
#
#     Y = image.img_to_array(img1)
#
#     X = np.expand_dims(Y,axis=0)
#     val = model.predict(X)
#     print(val)
#     if val == 1:
#
#         plt.xlabel("Duck",fontsize=20)
#
#
#     elif val == 0:
#
#         plt.xlabel("Bird",fontsize=20)

# %% [markdown]
# predictImage(file_directory)
