# %%
import matplotlib.pyplot as plt
import os, sys
import cv2
import PIL
import os.path
from PIL import Image, ImageOps
from skimage import color, io
import scipy.ndimage as ndi

# %%
dir = os.getcwd()

# %%
os.listdir(dir)
# Out:
# ['.ipynb_checkpoints',
#  '1.jpg',
#  '2.jpg',
#  '2_1.jpg',
#  '3.jpg',
#  '4.jpg',
#  'Brain-Tumor-Classification-Data-Wrangling.ipynb',
#  'Image_Preprocessing_Training.ipynb',
#  'l1.jpg']

# %%
img = plt.imread("2.jpg")
plt.imshow(img, cmap='gray')
type(img)
# Out:
# numpy.ndarray

# %%
img_gray = color.rgb2gray(img)/256
plt.imshow(img_gray)
img_gray.shape
# Out:
# (512, 512)

# %%
img_base = plt.imread('2.jpg')
print(img_base.shape)
plt.imshow(img_base)
# Out:
# (512, 512, 3)

# %%
# Transformation
img_base = Image.open('2.jpg')
try:
    gray_image = ImageOps.grayscale(img_base)
    img = gray_image.resize((224,224), PIL.Image.ANTIALIAS)
    img.save('2_1.jpg', quality=95)
except ValueError:
    print("There is something wrong")

# %%
type(img_base)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
img_new = plt.imread('2_1.jpg')
print(img_new.shape)
plt.imshow(img_new)
# Out:
# (224, 224)

# %%
img3 = io.imread("3.jpg")
type(img3)
# Out:
# numpy.ndarray

# %%
# Smooth "im" with Gaussian filters
im_s1 = ndi.gaussian_filter(img_base, sigma=1)
im_s3 = ndi.gaussian_filter(img_base, sigma=3)

# Draw bone masks of each image
fig, axes = plt.subplots(1,3, figsize=(12,6))
axes[0].imshow(img_base)
axes[0].set_title("Base")
axes[1].imshow(im_s1)
axes[1].set_title("sigma=1")
axes[2].imshow(im_s3)
axes[2].set_title("sigma=3")
plt.show()

# %%
"""

train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale=1./255)
train_generator = train_datagen.flow_from_directory(
        'data/train',
        target_size=(150, 150),
        batch_size=32,
        class_mode='binary')
validation_generator = test_datagen.flow_from_directory(
        'data/validation',
        target_size=(150, 150),
        batch_size=32,
        class_mode='binary')
model.fit(
        train_generator,
        steps_per_epoch=2000,
        epochs=50,
        validation_data=validation_generator,
        validation_steps=800)

"""

# %%
# Resizing an saving the test images in same folder with same file name

# for path in test_paths:
    for img_name in os.listdir(path):
        f_img = path+img_name
        img = Image.open(f_img)
        try:
            img = img.resize((512,512), PIL.Image.ANTIALIAS)
            img.save(f_img, quality=95)
        except ValueError:
            print("There is something wrong")

# %%
# Resizing an saving the training images in same folder with same file name

for path, new_path in zip(training_paths, new_training_paths):
    
    for img_name in os.listdir(path):
        
        if os.path.isfile(path+img_name):
        
            old_dir = path+img_name
            new_dir = new_path+img_name
            img = Image.open(old_dir)
            
            try:
                img_gray = ImageOps.grayscale(img)
                resized_gray = img_gray.resize((300,300), PIL.Image.ANTIALIAS)
                resized_gray.save(new_dir, quality=95)
            except ValueError:
                print("There is something wrong")
            
            
            
for img_name in os.listdir(path):
        f_img = path+img_name
        img = Image.open(f_img)
        #img_gray = img.convert('L')
        img_gray = ImageOps.grayscale(img)
        try:
            img_gray = img_gray.resize((300,300), PIL.Image.ANTIALIAS)
            img_gray.save(f_img, quality=95)
        except ValueError:
            print("There is something wrong") 
            
            
path = training_paths[3]
dirs = os.listdir(path)

def resize():
    for item in dirs:
        if os.path.isfile(path+item):
            im = Image.open(path+item)
            im = im.convert('RGB')
            f_img = path+item
            imResize = im.resize((512,512), Image.ANTIALIAS)
            imResize.save(f_img, quality=95)

resize()

# %%
# NoTumor Folder in Training subset

path = training_paths[3]
dirs = os.listdir(path)

def resize():
    for item in dirs:
        if os.path.isfile(path+item):
            im = Image.open(path+item)
            im = im.convert('RGB')
            f_img = path+item
            imResize = im.resize((512,512), Image.ANTIALIAS)
            imResize.save(f_img, quality=95)

resize()
